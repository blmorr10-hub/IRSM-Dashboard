# %% [markdown]
# <a href="https://colab.research.google.com/github/blmorr10-hub/IRSM-Dashboard/blob/main/IRSM_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repo so Colab has access to the files
# !git clone https://github.com/blmorr10-hub/IRSM-Dashboard.git
# %cd IRSM-Dashboard
# Run the dashboard generator
exec(open("IRSM_dashboard_generator.py").read())
from IPython.display import HTML, display
with open("IRSM_dashboard_output.html", "r") as f:
    display(HTML(f.read()))
